# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action="ignore")

# %%
data= pd.read_csv('/content/Usuarios.csv')
data
# Out:
#     Unnamed: 0   N estado_civil      grau_instrucao  n_filhos  salario  \
# 0            1   1     solteiro  ensino fundamental       NaN     4.00
# 1            2   2       casado  ensino fundamental       1.0     4.56
# 2            3   3       casado  ensino fundamental       2.0     5.25
# 3            4   4     solteiro        ensino medio       NaN     5.73
# 4            5   5     solteiro  ensino fundamental       NaN     6.26
# 5            6   6       casado  ensino fundamental       0.0     6.66
# 6            7   7     solteiro  ensino fundamental       NaN     6.86
# 7            8   8     solteiro  ensino fundamental       NaN     7.39
# 8            9   9       casado        ensino medio       1.0     7.59
# 9           10  10     solteiro        ensino medio       NaN     7.44
# 10          11  11       casado        ensino medio       2.0     8.12
# 11          12  12     solteiro  ensino fundamental       NaN     8.46
# ...

# %%
data.describe().T
# Out:
#              count       mean        std   min      25%     50%    75%   max
# Unnamed: 0    36.0  18.500000  10.535654   1.0   9.7500  18.500  27.25  36.0
# N             36.0  18.500000  10.535654   1.0   9.7500  18.500  27.25  36.0
# n_filhos      20.0   1.650000   1.268028   0.0   1.0000   2.000   2.00   5.0
# salario       36.0  11.122222   4.587458   4.0   7.5525  10.165  14.06  23.3
# idade_anos    36.0  34.583333   6.737422  20.0  30.0000  34.500  40.00  48.0
# idade_meses   36.0   5.611111   3.288749   0.0   3.7500   6.000   8.00  11.0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# N                   0
# estado_civil        0
# grau_instrucao      0
# n_filhos           16
# salario             0
# idade_anos          0
# idade_meses         0
# reg_procedencia     0
# dtype: int64

# %%
data.fillna(0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# N                  0
# estado_civil       0
# grau_instrucao     0
# n_filhos           0
# salario            0
# idade_anos         0
# idade_meses        0
# reg_procedencia    0
# dtype: int64

# %%
cat_col = data.select_dtypes(include=['object']).columns
num_col = data.select_dtypes(exclude=['object']).columns

# %%
# %matplotlib inline

# %%
data['estado_civil'].value_counts().plot.bar()

# %%
df_v=pd.DataFrame(data['grau_instrucao'].value_counts())
plot = df_v.plot.pie(y='grau_instrucao', figsize=(8, 8));

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(data[num_col].corr(),annot = True);
